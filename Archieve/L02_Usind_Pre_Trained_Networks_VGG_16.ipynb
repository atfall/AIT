# %% [markdown]
# <a href="https://colab.research.google.com/github/atfall/AIT/blob/main/L02_Usind_Pre_Trained_Networks_VGG_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Source: Francois Collet, Deep Learning with Python

# %% [markdown]
# # Using VGG16, a pre-trained model to recognize images

# %%
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input, decode_predictions ,VGG16
import numpy as np
import os 
# The local path to our target image
data_dir = r'/content/drive/MyDrive/Colab Notebooks/AIT-AS21/Exercises/data'
# use pfad kopieren: /content/drive/MyDrive/Colab Notebooks/AIT-AS21/Exercises/data/elephant.jpg
img_name = 'elephant.jpg'

# %%
# !ls sample_data
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
# getting full path to the image) 
img = os.path.join(data_dir, img_name)
print(img)
# Out:
# /content/drive/MyDrive/Colab Notebooks/AIT-AS21/Exercises/data/elephant.jpg

# %%
# !ls data_dir
# Out:
# ls: cannot access 'data_dir': No such file or directory

# %%
# task: show your image here - hint: use matplotlib.pyplot library
import matplotlib.pyplot as plt 
img = image.load_img(img, target_size=(224, 224))
plt.imshow(img)

# %%
print(img)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F012C12A7D0>

# %%
# create the numpy array from the picture: 
# `x` is a float32 Numpy array of shape (224, 224, 3)
x = image.img_to_array(img)

# We load the pre-trained model 
model = VGG16(weights="imagenet")

# We add a dimension to transform our array into a "batch"
# of size (1, 224, 224, 3)
x = np.expand_dims(x, axis=0)

# Finally we preprocess the batch
# (this does channel-wise color normalization)
x = preprocess_input(x)

preds = model.predict(x)
print('Predicted:', decode_predictions(preds))
# Out:
# Predicted: [[('n02504458', 'African_elephant', 0.90942055), ('n01871265', 'tusker', 0.086183496), ('n02504013', 'Indian_elephant', 0.0043545887), ('n02408429', 'water_buffalo', 3.9944516e-05), ('n02397096', 'warthog', 1.3171832e-06)]]

# %% [markdown]
# # Create your own picture or upload one from google pictures
# # E.g. you might choose a picture from a pizza and then try to detect it!

# %%
# show the list of all known classes 
decode_predictions(np.expand_dims(np.arange(1000),0),top = 100)
# Out:
# [[('n15075141', 'toilet_tissue', 999),
#   ('n13133613', 'ear', 998),
#   ('n13054560', 'bolete', 997),
#   ('n13052670', 'hen-of-the-woods', 996),
#   ('n13044778', 'earthstar', 995),
#   ('n13040303', 'stinkhorn', 994),
#   ('n13037406', 'gyromitra', 993),
#   ('n12998815', 'agaric', 992),
#   ('n12985857', 'coral_fungus', 991),
#   ('n12768682', 'buckeye', 990),
#   ('n12620546', 'hip', 989),
#   ('n12267677', 'acorn', 988),
#   ('n12144580', 'corn', 987),
#   ('n12057211', "yellow_lady's_slipper", 986),
#   ('n11939491', 'daisy', 985),
#   ('n11879895', 'rapeseed', 984),
#   ('n10565667', 'scuba_diver', 983),
#   ('n10148035', 'groom', 982),
#   ('n09835506', 'ballplayer', 981),
#   ('n09472597', 'volcano', 980),
#   ('n09468604', 'valley', 979),
#   ('n09428293', 'seashore', 978),
#   ('n09421951', 'sandbar', 977),
#   ('n09399592', 'promontory', 976),
#   ('n09332890', 'lakeside', 975),
#   ('n09288635', 'geyser', 974),
#   ('n09256479', 'coral_reef', 973),
# ...

# %% [markdown]
# from keras.preprocessing import image
# from keras.applications.vgg16 import preprocess_input, decode_predictions
# import numpy as np
