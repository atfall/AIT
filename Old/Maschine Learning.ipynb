# %%
from urllib.request import urlopen
from scipy.io import arff
import pandas as pd

url = 'https://gist.githubusercontent.com/grappler/581d84ef57c5f20d938bd00f3ec6200b/raw/7c3f79f92f5935145c37a764edca3c0adf2b540c/Project_Learning.arff'
f = urlopen(url)
myfile = f.read()
data = arff.loadarff(myfile)
df = pd.DataFrame(data[0])

df.head()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-910938e1455f> in <module>()
#       6 f = urlopen(url)
#       7 myfile = f.read()
# ----> 8 data = arff.loadarff(myfile)
#       9 df = pd.DataFrame(data[0])
#      10
#
# /usr/local/lib/python3.7/dist-packages/scipy/io/arff/arffread.py in loadarff(f)
#     801         ofile = f
#     802     else:
# --> 803         ofile = open(f, 'rt')
#     804     try:
#     805         return _loadarff(ofile)
#
# ...
